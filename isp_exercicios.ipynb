# %%
import pandas as pd

import numpy as np

# %%
url = 'https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv'
df = pd.read_csv(url, encoding = 'latin1', sep=';')
df.columns
# Out:
# Index(['cisp', 'mes', 'ano', 'mes_ano', 'aisp', 'risp', 'munic', 'mcirc',
#        'regiao', 'hom_doloso', 'lesao_corp_morte', 'latrocinio', 'cvli',
#        'hom_por_interv_policial', 'feminicidio', 'letalidade_violenta',
#        'tentat_hom', 'tentativa_feminicidio', 'lesao_corp_dolosa', 'estupro',
#        'hom_culposo', 'lesao_corp_culposa', 'roubo_transeunte',
#        'roubo_celular', 'roubo_em_coletivo', 'roubo_rua', 'roubo_veiculo',
#        'roubo_carga', 'roubo_comercio', 'roubo_residencia', 'roubo_banco',
#        'roubo_cx_eletronico', 'roubo_conducao_saque', 'roubo_apos_saque',
#        'roubo_bicicleta', 'outros_roubos', 'total_roubos', 'furto_veiculos',
#        'furto_transeunte', 'furto_coletivo', 'furto_celular',
#        'furto_bicicleta', 'outros_furtos', 'total_furtos', 'sequestro',
#        'extorsao', 'sequestro_relampago', 'estelionato', 'apreensao_drogas',
#        'posse_drogas', 'trafico_drogas', 'apreensao_drogas_sem_autor',
# ...

# %%
df_roubo_veiculo_dp = df.groupby('cisp')['roubo_veiculo'].sum().reset_index() # informação qualitativa utilizo parenteses (''); informação quantitativa utilizo colchetes ['']; reset_index() após o sum() visualizo o index
df_roubo_veiculo_dp = df_roubo_veiculo_dp.sort_values(by='roubo_veiculo', ascending = False) # ascending = False visualiza a linha do menor para o maior, ordeno as linhas da coluna
df_roubo_veiculo_dp
# Out:
#      cisp  roubo_veiculo
# 52     59          37866
# 57     64          32892
# 35     39          29753
# 23     27          27978
# 30     34          27596
# ..    ...            ...
# 77     92              8
# 116   140              8
# 115   139              7
# 113   137              6
# 114   138              2
#
# [138 rows x 2 columns]

# %%
array_roubo_veiculo_dp = np.array(df_roubo_veiculo_dp['roubo_veiculo'])

# %%
media = np.mean(array_roubo_veiculo_dp)
mediana = np.median(array_roubo_veiculo_dp)
q1 = np.percentile(array_roubo_veiculo_dp, 25)
q2 = np.percentile(array_roubo_veiculo_dp, 50)
q3 = np.percentile(array_roubo_veiculo_dp, 75)
print(f'Média {media}')
print(f'Mediana {mediana}')
print(f'Q1: {q1}')
print(f'Q2: {q2}')
print(f'Q3: {q3}')
# Out:
# Média 5260.95652173913
# Mediana 1228.5
# Q1: 104.0
# Q2: 1228.5
# Q3: 8125.0

# %%
distancia = (media - mediana) / mediana  # Número percentual por isso sai um percentual, depois é só formatar para %
print(distancia)

print(f'{distancia:.2%}')
# Out:
# 3.282422891118543
# 328.24%

# %%
df_top_25_roubo = df_roubo_veiculo_dp.loc[df_roubo_veiculo_dp['roubo_veiculo'] >q3]
df_top_25_roubo
# Out:
#     cisp  roubo_veiculo
# 52    59          37866
# 57    64          32892
# 35    39          29753
# 23    27          27978
# 30    34          27596
# 47    54          25018
# 53    60          20742
# 34    38          20072
# 17    21          19812
# 31    35          19480
# 36    40          19448
# 65    74          18430
# 29    33          18113
# 25    29          16977
# 51    58          16407
# 45    52          15685
# 18    22          15202
# 27    31          15165
# 40    44          14953
# 63    72          14231
# 64    73          14005
# 26    30          12886
# 50    57          12521
# 20    24          12144
# 49    56          12060
# 21    25          11083
# 24    28          11080
# 19    23          10813
# 66    75          10176
# 55    62           9304
# 16    20           9136
# 28    32           8752
# 46    53           8577
# 69    78           8576
# 62    71           8209

# %%
df_rb_veic_baix = df.loc[df['munic'] == 'Baixada Fluminense']
df_rb_veic_baix = df_rb_veic_baix.groupby('cisp')['roubo_veiculo'].sum().reset_index()
df_rb_veic_baix = df_rb_veic_baix.sort_values(by = 'roubo_veiculo', ascending = False)

# %%
array= np.array(df_rb_veic_baix['roubo_veiculo'])

# %%
q1 = np.percentile(array_roubo_veiculo_dp, 25)
q2 = np.percentile(array_roubo_veiculo_dp, 50)
q3 = np.percentile(array_roubo_veiculo_dp, 75)
print(f'Q1: {q1}')
print(f'Q2: {q2}')
print(f'Q3: {q3}')
# Out:
# Q1: 104.0
# Q2: 1228.5
# Q3: 8125.0

# %%
df_top_25_roub_veic_baix = df_roubo_veiculo_dp.loc[df_roubo_veiculo_dp['roubo_veiculo'] >q3]
df_top_25_roub_veic_baix
# Out:
#     cisp  roubo_veiculo
# 52    59          37866
# 57    64          32892
# 35    39          29753
# 23    27          27978
# 30    34          27596
# 47    54          25018
# 53    60          20742
# 34    38          20072
# 17    21          19812
# 31    35          19480
# 36    40          19448
# 65    74          18430
# 29    33          18113
# 25    29          16977
# 51    58          16407
# 45    52          15685
# 18    22          15202
# 27    31          15165
# 40    44          14953
# 63    72          14231
# 64    73          14005
# 26    30          12886
# 50    57          12521
# 20    24          12144
# 49    56          12060
# 21    25          11083
# 24    28          11080
# 19    23          10813
# 66    75          10176
# 55    62           9304
# 16    20           9136
# 28    32           8752
# 46    53           8577
# 69    78           8576
# 62    71           8209

# %%
df_ap_menores = df.groupby('cisp')['aaapai'].sum().reset_index()
df_ap_menores = df_ap_menores.sort_values(by='aaapai', ascending = False)
df_ap_menores
# Out:
#      cisp  aaapai
# 104   126  3736.0
# 8      12  3667.0
# 10     14  3368.0
# 65     74  3355.0
# 12     16  3233.0
# ..    ...     ...
# 130   156    19.0
# 129   155    16.0
# 131   157    14.0
# 94    111    13.0
# 77     92    12.0
#
# [138 rows x 2 columns]

# %%
array_df_ap_menores = np.array(df_ap_menores)
media = np.mean(array_df_ap_menores)
mediana = np.median(array_df_ap_menores)
print(f'Média {media}')
print(f'Mediana {mediana}')
# Out:
# Média 497.2391304347826
# Mediana 135.5

# %%
distancia = (media - mediana) / mediana  # Número percentual por isso sai um percentual, depois é só formatar para %
print(distancia)

print(f'{distancia:.2%}')
# Out:
# 2.669661479223488
# 266.97%

# %%
df_roub_rua_dp = df.groupby('cisp')['roubo_rua'].sum().reset_index()
df_roub_rua_dp = df_roub_rua_dp.sort_values(by='roubo_rua', ascending = False)
df_roub_rua_dp
# Out:
#      cisp  roubo_rua
# 52     59      87977
# 57     64      64885
# 30     34      58399
# 25     29      50260
# 65     74      47624
# ..    ...        ...
# 131   157         16
# 130   156         11
# 94    111          7
# 77     92          6
# 129   155          5
#
# [138 rows x 2 columns]

# %%
array_df_roub_rua_dp = np.array(df_roub_rua_dp)
media = np.mean(array_df_roub_rua_dp)
mediana = np.median(array_df_roub_rua_dp)
print(f'Média {media}')
print(f'Mediana {mediana}')
# Out:
# Média 6572.518115942029
# Mediana 134.5

# %%
distancia = (media - mediana) / mediana  # Número percentual por isso sai um percentual, depois é só formatar para %
print(distancia)

print(f'{distancia:.2%}')
# Out:
# 47.866305694736276
# 4786.63%

# %%
df_veiculos = df.groupby('cisp')[['furto_veiculos', 'roubo_veiculo', 'recuperacao_veiculos']].sum().reset_index()
df_veiculos = df_veiculos.sort_values(by='cisp')
df_veiculos.head(2)
# Out:
#    cisp  furto_veiculos  roubo_veiculo  recuperacao_veiculos
# 0     1            1945            583                   548
# 1     4            1274           2223                  1937

# %%
corr_pandas = df_veiculos[['furto_veiculos', 'roubo_veiculo', 'recuperacao_veiculos']].corr()
corr_pandas
# Out:
#                       furto_veiculos  roubo_veiculo  recuperacao_veiculos
# furto_veiculos              1.000000       0.773692              0.706661
# roubo_veiculo               0.773692       1.000000              0.927230
# recuperacao_veiculos        0.706661       0.927230              1.000000

# %%
import seaborn as sns


sns.heatmap(corr_pandas, annot=True, cmap='coolwarm', vmin=-1, vmax=1, fmt='.2f')
# Out:
# <Axes: >

# %%
df_roubos = df.groupby('cisp')[['latrocinio', 'tentat_hom', 'roubo_rua', 'roubo_celular']].sum().reset_index().sort_values(by='cisp')
df_roubos.head(2)
# Out:
#    cisp  latrocinio  tentat_hom  roubo_rua  roubo_celular
# 0     1          19         123      22790           4724
# 1     4          18         854      27988           4970

# %%
correlacao = np.corrcoef('latrocinio', 'tentat_hom', 'roubo_rua', 'roubo_celular')
sns.heatmap(correlacao, annot=True, cmap='coolwarm', vmin=-1, vmax=1, fmt='.2f')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 correlacao = np.corrcoef('latrocinio', 'tentat_hom', 'roubo_rua', 'roubo_celular')
#       2 sns.heatmap(correlacao, annot=True, cmap='coolwarm', vmin=-1, vmax=1, fmt='.2f')
#
# TypeError: corrcoef() takes from 1 to 3 positional arguments but 4 were given
