# %%
import time
import polars as pl
inicio = time.time()
df_jan =pl.read_csv('jan2026.csv',separator=';',encoding='latin-1')
df_fev = pl.read_csv( 'fev2026.csv',separator=';',encoding='latin-1')
df_mar = pl.read_csv( 'mar2026.csv',separator=';',encoding='latin-1')
# df_abr = pl.read_csv( 'abr2025.csv',separator=';',encoding='latin1')
# df_mai = pl.read_csv( 'mai2025.csv',separator=';',encoding='latin1')
# df_jun = pl.read_csv( 'jun2025.csv',separator=';',encoding='latin1')
df= pl.concat([df_jan, df_fev, df_mar])
print(df)
fim = time.time()
print(f'Polars: {fim - inicio:.2f}s')
# Out:
# shape: (57_640_659, 9)
# ┌────────────┬────────────┬─────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ MÊS COMPET ┆ MÊS        ┆ UF  ┆ CÓDIGO     ┆ … ┆ CPF        ┆ NIS        ┆ NOME FAVO ┆ VALOR     │
# │ ÊNCIA      ┆ REFERÊNCIA ┆ --- ┆ MUNICÍPIO  ┆   ┆ FAVORECIDO ┆ FAVORECIDO ┆ RECIDO    ┆ PARCELA   │
# │ ---        ┆ ---        ┆ str ┆ SIAFI      ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │ i64        ┆ i64        ┆     ┆ ---        ┆   ┆ str        ┆ i64        ┆ str       ┆ str       │
# │            ┆            ┆     ┆ i64        ┆   ┆            ┆            ┆           ┆           │
# ╞════════════╪════════════╪═════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 202601     ┆ 202502     ┆ MG  ┆ 5041       ┆ … ┆            ┆ 1652366711 ┆ MILENE    ┆ 850,00    │
# │            ┆            ┆     ┆            ┆   ┆            ┆ 2          ┆ APARECIDA ┆           │
# ...
