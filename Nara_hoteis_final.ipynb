# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("funcionarios.csv", sep=';')
df
# Out:
#      id_funcionario  id_unidade            nome                cargo  \
# 0                 1           1   Gabriela Lima  Auxiliar de Limpeza
# 1                 2           1    Abel Correia            Segurança
# 2                 3           1   Sara Teixeira  analista financeiro
# 3                 4           1  Julia Monteiro  Auxiliar de Limpeza
# 4                 5           1   Daniela Ramos  Auxiliar de Limpeza
# ..              ...         ...             ...                  ...
# 129             130          12   Fernanda Cruz           Manutenção
# 130             131          12    Abel Correia              Gerente
# 131             132          12     Yuri Castro        Recepcionista
# 132             133          12     Yuri Castro            segurança
# 133             134          12   Eduardo Lopes        Recepcionista
#
#       departamento     salario data_admissao
# 0       Governança  "2.139,00"    2020-10-05
# 1        Segurança  "1.746,00"    2021-12-29
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_funcionario  134 non-null    int64
#  1   id_unidade      134 non-null    int64
#  2   nome            134 non-null    str
#  3   cargo           134 non-null    str
#  4   departamento    134 non-null    str
#  5   salario         128 non-null    str
#  6   data_admissao   134 non-null    str
# dtypes: int64(2), str(5)
# memory usage: 7.5 KB

# %%
df.dtypes
# Out:
# id_funcionario    int64
# id_unidade        int64
# nome                str
# cargo               str
# departamento        str
# salario             str
# data_admissao       str
# dtype: object

# %%
df.isnull().sum().reset_index()
# Out:
#             index  0
# 0  id_funcionario  0
# 1      id_unidade  0
# 2            nome  0
# 3           cargo  0
# 4    departamento  0
# 5         salario  6
# 6   data_admissao  0

# %%
df[df.isnull().any(axis=1)]
# Out:
#      id_funcionario  id_unidade                nome                cargo  \
# 8                 9           1         Bruno Costa  Auxiliar de Limpeza
# 13               14           1         Yuri Castro  Analista Financeiro
# 36               37           4       Larissa Sousa           cozinheiro
# 42               43           4       Wilson Duarte  Analista Financeiro
# 91               92           9       Wilson Duarte              Gerente
# 103             104          10  Vanessa Cavalcanti           COZINHEIRO
#
#             departamento salario data_admissao
# 8             Governança     NaN    2021-11-02
# 13            Financeiro     NaN    2022-12-31
# 36   Alimentos e Bebidas     NaN    2019-09-29
# 42            Financeiro     NaN    2022-01-07
# 91         Administração     NaN    2024-02-29
# 103  Alimentos e Bebidas     NaN    2024-05-27

# %%
df[df.duplicated(subset=['nome','departamento', 'cargo'], keep=False)].sort_values(by='nome')
# Out:
#      id_funcionario  id_unidade            nome                cargo  \
# 0                 1           1   Gabriela Lima  Auxiliar de Limpeza
# 45               46           5   Gabriela Lima  Auxiliar de Limpeza
# 31               32           3   Gabriela Lima  Auxiliar de Limpeza
# 84               85           9  Natalia Campos  Analista Financeiro
# 53               54           6  Natalia Campos  Analista Financeiro
# 65               66           6   Nicolas Cunha           Cozinheiro
# 15               16           2   Nicolas Cunha           Cozinheiro
# 82               83           8    Thiago Matos            Segurança
# 46               47           5    Thiago Matos            Segurança
# 33               34           4    Ursula Pinto           Manutenção
# 74               75           7    Ursula Pinto           Manutenção
# 116             117          11    Ursula Pinto           Manutenção
# 63               64           6   Wilson Duarte        Recepcionista
# ...

# %%
df['cargo'] = df['cargo'].str.strip().str.title()

# %%
df['cargo'].value_counts().reset_index()
# Out:
#                  cargo  count
# 0           Manutenção     24
# 1            Camareira     21
# 2            Segurança     20
# 3  Auxiliar De Limpeza     17
# 4        Recepcionista     15
# 5           Cozinheiro     15
# 6  Analista Financeiro     13
# 7              Gerente      9

# %%
df['departamento'].value_counts().reset_index()
# Out:
#           departamento  count
# 0           Governança     30
# 1           Manutenção     24
# 2            Segurança     20
# 3             Recepção     15
# 4           Financeiro     13
# 5  Alimentos e Bebidas     13
# 6                 Gov.      8
# 7        Administração      8
# 8                  A&B      2
# 9               Admin.      1

# %%
mapa = {
'Gov.':'Governança',
'Admin.':'Administração',
'A&B':'Alimentos e Bebidas',
}
df['departamento'] = df['departamento'].map(mapa).fillna(df['departamento'])

# %%
df['salario'] = df['salario'].astype(str)\
.str.replace('"','',regex=False)\
.str.replace("'"," ",regex=False)\
.str.replace('-','',regex=False)\
.str.replace(',','.',regex=False).str.strip().astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 5
#       1 df['salario'] = df['salario'].astype(str)\
#       2 .str.replace('"','',regex=False)\
#       3 .str.replace("'"," ",regex=False)\
#       4 .str.replace('-','',regex=False)\
# ----> 5 .str.replace(',','.',regex=False).str.strip().astype(float)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:6529, in NDFrame.astype(self, dtype, copy, errors)
#    6525             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6526
#    6527         else:
#    6528             # else, only a single dtype is given
# -> 6529             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6530             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6531             return res.__finalize__(self, method="astype")
#    6532
#
# ...

# %%
df

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_funcionario  134 non-null    int64
#  1   id_unidade      134 non-null    int64
#  2   nome            134 non-null    str
#  3   cargo           134 non-null    str
#  4   departamento    134 non-null    str
#  5   salario         128 non-null    float64
#  6   data_admissao   134 non-null    datetime64[us]
# dtypes: datetime64[us](1), float64(1), int64(2), str(3)
# memory usage: 7.5 KB

# %%
df['data_admissao'] = pd.to_datetime(
    df['data_admissao'],
    format='mixed',
    dayfirst=True,
    errors='coerce'
)

print('Tipo:', df['data_admissao'].dtype)
df.isnull().sum().reset_index()
# Out:
# Tipo: datetime64[us]
#             index  0
# 0  id_funcionario  0
# 1      id_unidade  0
# 2            nome  0
# 3           cargo  0
# 4    departamento  0
# 5         salario  6
# 6   data_admissao  0
