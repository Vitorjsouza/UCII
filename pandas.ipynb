# %%
import time
import pandas as pd
inicio = time.time()
df_jan = pd.read_csv( 'jan2026.csv',sep=';',encoding='latin-1')
df_fev = pd.read_csv( 'fev2026.csv',sep=';',encoding='latin-1')
df_mar = pd.read_csv( 'mar2026.csv',sep=';',encoding='latin-1')
# df_abr = pd.read_csv( 'abr25.csv',sep=';',encoding='latin-1')
# df_mai = pd.read_csv( 'mai2025.csv',sep=';',encoding='latin-1')
# df_jun = pd.read_csv( 'jun2025.csv',sep=';',encoding='latin-1')
df= pd.concat([df_jan, df_fev, df_mar],ignore_index=True)
fim = time.time()
print(f'Pandas: {fim - inicio:.2f}s')
# Out:
# Pandas: 148.40s
